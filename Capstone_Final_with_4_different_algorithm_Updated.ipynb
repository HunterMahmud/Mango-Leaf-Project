# %% [markdown]
# Importing Required Module

# %%
import os
import random
import pickle
import numpy as np
import pandas as pd
import seaborn as sns
import tensorflow as tf
from keras import Sequential
from tensorflow import keras
import matplotlib.pyplot as plt
from keras.callbacks import TensorBoard
from keras.applications import InceptionV3
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import load_model
from tensorflow.keras.callbacks import ModelCheckpoint
from keras.layers import Dense,Flatten,Conv2D,MaxPooling2D,Dropout,BatchNormalization
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from tensorflow.keras.preprocessing.image import ImageDataGenerator, load_img, img_to_array

print("[INFO]: Tensorflow version{}".format(tf.__version__))
state_gpu = tf.test.gpu_device_name()
print("[INFO]: GPU usage{0}".format(state_gpu))
# Out:
# [INFO]: Tensorflow version2.12.0
# [INFO]: GPU usage/device:GPU:0

# %% [markdown]
# Allocating file from google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Extracting Dataset

# %%
import zipfile
zip_ref = zipfile.ZipFile('/content/drive/MyDrive/Mango Datasets/MangoLeafBD_Dataset.zip','r')
zip_ref.extractall('/content')
zip_ref.close()

# %% [markdown]
# Getting Directory Path and Class Labelling

# %%
# getting current directory
current_directory = os.getcwd()

Mango_dataset = os.path.join(current_directory,'MangoLeafBD Dataset')
class_labels = [f for f in os.listdir(Mango_dataset) if os.path.isdir(os.path.join(Mango_dataset, f))]
class_labels
# Out:
# ['Cutting Weevil',
#  'Anthracnose',
#  'Die Back',
#  'Powdery Mildew',
#  'Healthy',
#  'Sooty Mould',
#  'Gall Midge',
#  'Bacterial Canker']

# %%
# Set the data directory and label information
data_dir = '/content/MangoLeafBD Dataset'

# %%
# Create a DataFrame with image paths and labels
data = []
for i, class_name in enumerate(class_labels):
    class_dir = os.path.join(data_dir, class_name)
    file_names = os.listdir(class_dir)
    for file_name in file_names:
        file_path = os.path.join(class_dir, file_name)
        label = i
        data.append((file_path, label))

df = pd.DataFrame(data, columns=['image_path', 'label'])
df['label'] = df['label'].astype(str)
df['image_path'] = df['image_path'].astype(str)
# Shuffle the data and split into train and validation sets
df = df.sample(frac=1).reset_index(drop=True)
train_split = 0.8
num_train = int(len(df) * train_split)
train_df = df[:num_train]
val_df = df[num_train:]

# %% [markdown]
# Showing Sample Image from Each Group

# %%
from PIL import Image
# Set the target size for the images
target_size = (300, 300)

# Set the number of images to display for each class
num_images = 7

# Display the images from the DataFrame
fig, axes = plt.subplots(len(class_labels), num_images, figsize=(10, 12))

for i, class_name in enumerate(class_labels):
    class_df = train_df[train_df['label'] == str(i)]
    class_samples = class_df.sample(num_images)
    
    for j, (_, row) in enumerate(class_samples.iterrows()):
        image_path = row['image_path']
        image = Image.open(image_path).resize(target_size)
        axes[i][j].imshow(image)
        axes[i][j].axis('off')
        
        if j == 0:
            axes[i][j].set_title(class_name)
        
plt.show()

# %% [markdown]
# Data augmentation for training and validation

# %%
train_datagen = ImageDataGenerator(rescale=1./255)

val_datagen = ImageDataGenerator(rescale=1./255)

# %% [markdown]
# Defining image size, batch size and data generating for testing and validation

# %%
img_size = (224,224)
batch_size = 32

#generating data

train_generator = train_datagen.flow_from_dataframe(dataframe=train_df,
                                                     x_col='image_path',
                                                     y_col='label',
                                                     target_size=img_size,
                                                     batch_size=batch_size,
                                                     class_mode='categorical')


val_generator = val_datagen.flow_from_dataframe(dataframe=val_df,
                                                 x_col='image_path',
                                                 y_col='label',
                                                 target_size=img_size,
                                                 batch_size=batch_size,
                                                 class_mode='categorical')
# Out:
# Found 3200 validated image filenames belonging to 8 classes.
# Found 800 validated image filenames belonging to 8 classes.

# %% [markdown]
# 1. Simple CNN model defining

# %%
# Build and compile a simple CNN model
model1 = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(224, 224, 3)),
    MaxPooling2D((2, 2)),
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D((2, 2)),
    Flatten(),
    Dense(64, activation='relu'),
    Dense(len(class_labels), activation='softmax')
])

# %% [markdown]
# 2. Model using VGG16

# %%
from keras.applications.vgg16 import VGG16
#base_model_weights_path = '/kaggle/input/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5'
base_model_vgg16 = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

x = keras.layers.Flatten() (base_model_vgg16.output)
x = keras.layers.Dense(256, activation="relu")(x)
x = keras.layers.Dropout(0.25)(x)
output = keras.layers.Dense(8, activation='softmax')(x)
model2 = keras.models.Model(inputs=base_model_vgg16.input, outputs=output)


for layer in base_model_vgg16.layers:
    layer.trainable = False

# %% [markdown]
# 3. Model using VGG19

# %%
from keras.applications.vgg19 import VGG19
base_model_vgg19 = VGG19(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

x = keras.layers.Flatten() (base_model_vgg19.output)
x = keras.layers.Dense(256, activation="relu")(x)
x = keras.layers.Dropout(0.25)(x)
output = keras.layers.Dense(8, activation='softmax')(x)
model3 = keras.models.Model(inputs=base_model_vgg19.input, outputs=output)


for layer in base_model_vgg19.layers:
    layer.trainable = False

# %% [markdown]
# 4. Model using Inception V3

# %%
base_model_inceptionv3 = InceptionV3(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

# Add custom layers on top of the base model
x = Flatten()(base_model_inceptionv3.output)
x = Dense(256, activation='relu')(x)
x = Dropout(0.25)(x)
output = Dense(len(class_labels), activation='softmax')(x)
model4 = keras.models.Model(inputs=base_model_inceptionv3.input, outputs=output)

# Freeze the base model layers
for layer in base_model_inceptionv3.layers:
    layer.trainable = False

# %% [markdown]
# Summary of Normal CNN model

# %%
model1.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_97 (Conv2D)          (None, 222, 222, 32)      896
#
#  max_pooling2d_7 (MaxPooling  (None, 111, 111, 32)     0
#  2D)
#
#  conv2d_98 (Conv2D)          (None, 109, 109, 64)      18496
#
#  max_pooling2d_8 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_99 (Conv2D)          (None, 52, 52, 128)       73856
#
#  max_pooling2d_9 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  flatten_6 (Flatten)         (None, 86528)             0
#
#  dense_12 (Dense)            (None, 64)                5537856
#
#  dense_13 (Dense)            (None, 8)                 520
#
# =================================================================
# Total params: 5,631,624
# Trainable params: 5,631,624
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Summary of VGG16

# %%
model2.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_6 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_7 (Flatten)         (None, 25088)             0
#
#  dense_14 (Dense)            (None, 256)               6422784
#
#  dropout_5 (Dropout)         (None, 256)               0
#
#  dense_15 (Dense)            (None, 8)                 2056
#
# =================================================================
# Total params: 21,139,528
# Trainable params: 6,424,840
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %% [markdown]
# Summary of VGG19

# %%
model3.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv4 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv4 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv4 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  flatten_8 (Flatten)         (None, 25088)             0
#
#  dense_16 (Dense)            (None, 256)               6422784
#
#  dropout_6 (Dropout)         (None, 256)               0
#
#  dense_17 (Dense)            (None, 8)                 2056
#
# =================================================================
# Total params: 26,449,224
# Trainable params: 6,424,840
# Non-trainable params: 20,024,384
# _________________________________________________________________

# %% [markdown]
# Summary of Inception V3

# %%
model4.summary()
# Out:
# Model: "model_7"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_8 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv2d_100 (Conv2D)            (None, 111, 111, 32  864         ['input_8[0][0]']
#                                 )
#
#  batch_normalization_94 (BatchN  (None, 111, 111, 32  96         ['conv2d_100[0][0]']
#  ormalization)                  )
#
#  activation_94 (Activation)     (None, 111, 111, 32  0           ['batch_normalization_94[0][0]']
#                                 )
#
#  conv2d_101 (Conv2D)            (None, 109, 109, 32  9216        ['activation_94[0][0]']
#                                 )
#
#  batch_normalization_95 (BatchN  (None, 109, 109, 32  96         ['conv2d_101[0][0]']
#  ormalization)                  )
#
#  activation_95 (Activation)     (None, 109, 109, 32  0           ['batch_normalization_95[0][0]']
#                                 )
#
#  conv2d_102 (Conv2D)            (None, 109, 109, 64  18432       ['activation_95[0][0]']
#                                 )
#
#  batch_normalization_96 (BatchN  (None, 109, 109, 64  192        ['conv2d_102[0][0]']
#  ormalization)                  )
#
#  activation_96 (Activation)     (None, 109, 109, 64  0           ['batch_normalization_96[0][0]']
#                                 )
#
#  max_pooling2d_10 (MaxPooling2D  (None, 54, 54, 64)  0           ['activation_96[0][0]']
#  )
#
#  conv2d_103 (Conv2D)            (None, 54, 54, 80)   5120        ['max_pooling2d_10[0][0]']
#
#  batch_normalization_97 (BatchN  (None, 54, 54, 80)  240         ['conv2d_103[0][0]']
#  ormalization)
#
#  activation_97 (Activation)     (None, 54, 54, 80)   0           ['batch_normalization_97[0][0]']
#
#  conv2d_104 (Conv2D)            (None, 52, 52, 192)  138240      ['activation_97[0][0]']
#
#  batch_normalization_98 (BatchN  (None, 52, 52, 192)  576        ['conv2d_104[0][0]']
#  ormalization)
#
#  activation_98 (Activation)     (None, 52, 52, 192)  0           ['batch_normalization_98[0][0]']
#
#  max_pooling2d_11 (MaxPooling2D  (None, 25, 25, 192)  0          ['activation_98[0][0]']
#  )
#
#  conv2d_108 (Conv2D)            (None, 25, 25, 64)   12288       ['max_pooling2d_11[0][0]']
#
#  batch_normalization_102 (Batch  (None, 25, 25, 64)  192         ['conv2d_108[0][0]']
#  Normalization)
#
#  activation_102 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_102[0][0]']
#
#  conv2d_106 (Conv2D)            (None, 25, 25, 48)   9216        ['max_pooling2d_11[0][0]']
#
#  conv2d_109 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_102[0][0]']
#
#  batch_normalization_100 (Batch  (None, 25, 25, 48)  144         ['conv2d_106[0][0]']
#  Normalization)
#
#  batch_normalization_103 (Batch  (None, 25, 25, 96)  288         ['conv2d_109[0][0]']
#  Normalization)
#
#  activation_100 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_100[0][0]']
#
#  activation_103 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_103[0][0]']
#
#  average_pooling2d_9 (AveragePo  (None, 25, 25, 192)  0          ['max_pooling2d_11[0][0]']
#  oling2D)
#
#  conv2d_105 (Conv2D)            (None, 25, 25, 64)   12288       ['max_pooling2d_11[0][0]']
#
#  conv2d_107 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_100[0][0]']
#
#  conv2d_110 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_103[0][0]']
#
#  conv2d_111 (Conv2D)            (None, 25, 25, 32)   6144        ['average_pooling2d_9[0][0]']
#
#  batch_normalization_99 (BatchN  (None, 25, 25, 64)  192         ['conv2d_105[0][0]']
#  ormalization)
#
#  batch_normalization_101 (Batch  (None, 25, 25, 64)  192         ['conv2d_107[0][0]']
#  Normalization)
#
#  batch_normalization_104 (Batch  (None, 25, 25, 96)  288         ['conv2d_110[0][0]']
#  Normalization)
#
#  batch_normalization_105 (Batch  (None, 25, 25, 32)  96          ['conv2d_111[0][0]']
#  Normalization)
#
#  activation_99 (Activation)     (None, 25, 25, 64)   0           ['batch_normalization_99[0][0]']
#
#  activation_101 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_101[0][0]']
#
#  activation_104 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_104[0][0]']
#
#  activation_105 (Activation)    (None, 25, 25, 32)   0           ['batch_normalization_105[0][0]']
#
#  mixed0 (Concatenate)           (None, 25, 25, 256)  0           ['activation_99[0][0]',
#                                                                   'activation_101[0][0]',
#                                                                   'activation_104[0][0]',
#                                                                   'activation_105[0][0]']
#
#  conv2d_115 (Conv2D)            (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  batch_normalization_109 (Batch  (None, 25, 25, 64)  192         ['conv2d_115[0][0]']
#  Normalization)
#
#  activation_109 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_109[0][0]']
#
#  conv2d_113 (Conv2D)            (None, 25, 25, 48)   12288       ['mixed0[0][0]']
#
#  conv2d_116 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_109[0][0]']
#
#  batch_normalization_107 (Batch  (None, 25, 25, 48)  144         ['conv2d_113[0][0]']
#  Normalization)
#
#  batch_normalization_110 (Batch  (None, 25, 25, 96)  288         ['conv2d_116[0][0]']
#  Normalization)
#
#  activation_107 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_107[0][0]']
#
#  activation_110 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_110[0][0]']
#
#  average_pooling2d_10 (AverageP  (None, 25, 25, 256)  0          ['mixed0[0][0]']
#  ooling2D)
#
#  conv2d_112 (Conv2D)            (None, 25, 25, 64)   16384       ['mixed0[0][0]']
#
#  conv2d_114 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_107[0][0]']
#
#  conv2d_117 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_110[0][0]']
#
#  conv2d_118 (Conv2D)            (None, 25, 25, 64)   16384       ['average_pooling2d_10[0][0]']
#
#  batch_normalization_106 (Batch  (None, 25, 25, 64)  192         ['conv2d_112[0][0]']
#  Normalization)
#
#  batch_normalization_108 (Batch  (None, 25, 25, 64)  192         ['conv2d_114[0][0]']
#  Normalization)
#
#  batch_normalization_111 (Batch  (None, 25, 25, 96)  288         ['conv2d_117[0][0]']
#  Normalization)
#
#  batch_normalization_112 (Batch  (None, 25, 25, 64)  192         ['conv2d_118[0][0]']
#  Normalization)
#
#  activation_106 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_106[0][0]']
#
#  activation_108 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_108[0][0]']
#
#  activation_111 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_111[0][0]']
#
#  activation_112 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_112[0][0]']
#
#  mixed1 (Concatenate)           (None, 25, 25, 288)  0           ['activation_106[0][0]',
#                                                                   'activation_108[0][0]',
#                                                                   'activation_111[0][0]',
#                                                                   'activation_112[0][0]']
#
#  conv2d_122 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  batch_normalization_116 (Batch  (None, 25, 25, 64)  192         ['conv2d_122[0][0]']
#  Normalization)
#
#  activation_116 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_116[0][0]']
#
#  conv2d_120 (Conv2D)            (None, 25, 25, 48)   13824       ['mixed1[0][0]']
#
#  conv2d_123 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_116[0][0]']
#
#  batch_normalization_114 (Batch  (None, 25, 25, 48)  144         ['conv2d_120[0][0]']
#  Normalization)
#
#  batch_normalization_117 (Batch  (None, 25, 25, 96)  288         ['conv2d_123[0][0]']
#  Normalization)
#
#  activation_114 (Activation)    (None, 25, 25, 48)   0           ['batch_normalization_114[0][0]']
#
#  activation_117 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_117[0][0]']
#
#  average_pooling2d_11 (AverageP  (None, 25, 25, 288)  0          ['mixed1[0][0]']
#  ooling2D)
#
#  conv2d_119 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed1[0][0]']
#
#  conv2d_121 (Conv2D)            (None, 25, 25, 64)   76800       ['activation_114[0][0]']
#
#  conv2d_124 (Conv2D)            (None, 25, 25, 96)   82944       ['activation_117[0][0]']
#
#  conv2d_125 (Conv2D)            (None, 25, 25, 64)   18432       ['average_pooling2d_11[0][0]']
#
#  batch_normalization_113 (Batch  (None, 25, 25, 64)  192         ['conv2d_119[0][0]']
#  Normalization)
#
#  batch_normalization_115 (Batch  (None, 25, 25, 64)  192         ['conv2d_121[0][0]']
#  Normalization)
#
#  batch_normalization_118 (Batch  (None, 25, 25, 96)  288         ['conv2d_124[0][0]']
#  Normalization)
#
#  batch_normalization_119 (Batch  (None, 25, 25, 64)  192         ['conv2d_125[0][0]']
#  Normalization)
#
#  activation_113 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_113[0][0]']
#
#  activation_115 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_115[0][0]']
#
#  activation_118 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_118[0][0]']
#
#  activation_119 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_119[0][0]']
#
#  mixed2 (Concatenate)           (None, 25, 25, 288)  0           ['activation_113[0][0]',
#                                                                   'activation_115[0][0]',
#                                                                   'activation_118[0][0]',
#                                                                   'activation_119[0][0]']
#
#  conv2d_127 (Conv2D)            (None, 25, 25, 64)   18432       ['mixed2[0][0]']
#
#  batch_normalization_121 (Batch  (None, 25, 25, 64)  192         ['conv2d_127[0][0]']
#  Normalization)
#
#  activation_121 (Activation)    (None, 25, 25, 64)   0           ['batch_normalization_121[0][0]']
#
#  conv2d_128 (Conv2D)            (None, 25, 25, 96)   55296       ['activation_121[0][0]']
#
#  batch_normalization_122 (Batch  (None, 25, 25, 96)  288         ['conv2d_128[0][0]']
#  Normalization)
#
#  activation_122 (Activation)    (None, 25, 25, 96)   0           ['batch_normalization_122[0][0]']
#
#  conv2d_126 (Conv2D)            (None, 12, 12, 384)  995328      ['mixed2[0][0]']
#
#  conv2d_129 (Conv2D)            (None, 12, 12, 96)   82944       ['activation_122[0][0]']
#
#  batch_normalization_120 (Batch  (None, 12, 12, 384)  1152       ['conv2d_126[0][0]']
#  Normalization)
#
#  batch_normalization_123 (Batch  (None, 12, 12, 96)  288         ['conv2d_129[0][0]']
#  Normalization)
#
#  activation_120 (Activation)    (None, 12, 12, 384)  0           ['batch_normalization_120[0][0]']
#
#  activation_123 (Activation)    (None, 12, 12, 96)   0           ['batch_normalization_123[0][0]']
#
#  max_pooling2d_12 (MaxPooling2D  (None, 12, 12, 288)  0          ['mixed2[0][0]']
#  )
#
#  mixed3 (Concatenate)           (None, 12, 12, 768)  0           ['activation_120[0][0]',
#                                                                   'activation_123[0][0]',
#                                                                   'max_pooling2d_12[0][0]']
#
#  conv2d_134 (Conv2D)            (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  batch_normalization_128 (Batch  (None, 12, 12, 128)  384        ['conv2d_134[0][0]']
#  Normalization)
#
#  activation_128 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_128[0][0]']
#
#  conv2d_135 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_128[0][0]']
#
#  batch_normalization_129 (Batch  (None, 12, 12, 128)  384        ['conv2d_135[0][0]']
#  Normalization)
#
#  activation_129 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_129[0][0]']
#
#  conv2d_131 (Conv2D)            (None, 12, 12, 128)  98304       ['mixed3[0][0]']
#
#  conv2d_136 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_129[0][0]']
#
#  batch_normalization_125 (Batch  (None, 12, 12, 128)  384        ['conv2d_131[0][0]']
#  Normalization)
#
#  batch_normalization_130 (Batch  (None, 12, 12, 128)  384        ['conv2d_136[0][0]']
#  Normalization)
#
#  activation_125 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_125[0][0]']
#
#  activation_130 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_130[0][0]']
#
#  conv2d_132 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_125[0][0]']
#
#  conv2d_137 (Conv2D)            (None, 12, 12, 128)  114688      ['activation_130[0][0]']
#
#  batch_normalization_126 (Batch  (None, 12, 12, 128)  384        ['conv2d_132[0][0]']
#  Normalization)
#
#  batch_normalization_131 (Batch  (None, 12, 12, 128)  384        ['conv2d_137[0][0]']
#  Normalization)
#
#  activation_126 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_126[0][0]']
#
#  activation_131 (Activation)    (None, 12, 12, 128)  0           ['batch_normalization_131[0][0]']
#
#  average_pooling2d_12 (AverageP  (None, 12, 12, 768)  0          ['mixed3[0][0]']
#  ooling2D)
#
#  conv2d_130 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed3[0][0]']
#
#  conv2d_133 (Conv2D)            (None, 12, 12, 192)  172032      ['activation_126[0][0]']
#
#  conv2d_138 (Conv2D)            (None, 12, 12, 192)  172032      ['activation_131[0][0]']
#
#  conv2d_139 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_12[0][0]']
#
#  batch_normalization_124 (Batch  (None, 12, 12, 192)  576        ['conv2d_130[0][0]']
#  Normalization)
#
#  batch_normalization_127 (Batch  (None, 12, 12, 192)  576        ['conv2d_133[0][0]']
#  Normalization)
#
#  batch_normalization_132 (Batch  (None, 12, 12, 192)  576        ['conv2d_138[0][0]']
#  Normalization)
#
#  batch_normalization_133 (Batch  (None, 12, 12, 192)  576        ['conv2d_139[0][0]']
#  Normalization)
#
#  activation_124 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_124[0][0]']
#
#  activation_127 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_127[0][0]']
#
#  activation_132 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_132[0][0]']
#
#  activation_133 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_133[0][0]']
#
#  mixed4 (Concatenate)           (None, 12, 12, 768)  0           ['activation_124[0][0]',
#                                                                   'activation_127[0][0]',
#                                                                   'activation_132[0][0]',
#                                                                   'activation_133[0][0]']
#
#  conv2d_144 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  batch_normalization_138 (Batch  (None, 12, 12, 160)  480        ['conv2d_144[0][0]']
#  Normalization)
#
#  activation_138 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_138[0][0]']
#
#  conv2d_145 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_138[0][0]']
#
#  batch_normalization_139 (Batch  (None, 12, 12, 160)  480        ['conv2d_145[0][0]']
#  Normalization)
#
#  activation_139 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_139[0][0]']
#
#  conv2d_141 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed4[0][0]']
#
#  conv2d_146 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_139[0][0]']
#
#  batch_normalization_135 (Batch  (None, 12, 12, 160)  480        ['conv2d_141[0][0]']
#  Normalization)
#
#  batch_normalization_140 (Batch  (None, 12, 12, 160)  480        ['conv2d_146[0][0]']
#  Normalization)
#
#  activation_135 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_135[0][0]']
#
#  activation_140 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_140[0][0]']
#
#  conv2d_142 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_135[0][0]']
#
#  conv2d_147 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_140[0][0]']
#
#  batch_normalization_136 (Batch  (None, 12, 12, 160)  480        ['conv2d_142[0][0]']
#  Normalization)
#
#  batch_normalization_141 (Batch  (None, 12, 12, 160)  480        ['conv2d_147[0][0]']
#  Normalization)
#
#  activation_136 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_136[0][0]']
#
#  activation_141 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_141[0][0]']
#
#  average_pooling2d_13 (AverageP  (None, 12, 12, 768)  0          ['mixed4[0][0]']
#  ooling2D)
#
#  conv2d_140 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed4[0][0]']
#
#  conv2d_143 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_136[0][0]']
#
#  conv2d_148 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_141[0][0]']
#
#  conv2d_149 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_13[0][0]']
#
#  batch_normalization_134 (Batch  (None, 12, 12, 192)  576        ['conv2d_140[0][0]']
#  Normalization)
#
#  batch_normalization_137 (Batch  (None, 12, 12, 192)  576        ['conv2d_143[0][0]']
#  Normalization)
#
#  batch_normalization_142 (Batch  (None, 12, 12, 192)  576        ['conv2d_148[0][0]']
#  Normalization)
#
#  batch_normalization_143 (Batch  (None, 12, 12, 192)  576        ['conv2d_149[0][0]']
#  Normalization)
#
#  activation_134 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_134[0][0]']
#
#  activation_137 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_137[0][0]']
#
#  activation_142 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_142[0][0]']
#
#  activation_143 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_143[0][0]']
#
#  mixed5 (Concatenate)           (None, 12, 12, 768)  0           ['activation_134[0][0]',
#                                                                   'activation_137[0][0]',
#                                                                   'activation_142[0][0]',
#                                                                   'activation_143[0][0]']
#
#  conv2d_154 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  batch_normalization_148 (Batch  (None, 12, 12, 160)  480        ['conv2d_154[0][0]']
#  Normalization)
#
#  activation_148 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_148[0][0]']
#
#  conv2d_155 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_148[0][0]']
#
#  batch_normalization_149 (Batch  (None, 12, 12, 160)  480        ['conv2d_155[0][0]']
#  Normalization)
#
#  activation_149 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_149[0][0]']
#
#  conv2d_151 (Conv2D)            (None, 12, 12, 160)  122880      ['mixed5[0][0]']
#
#  conv2d_156 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_149[0][0]']
#
#  batch_normalization_145 (Batch  (None, 12, 12, 160)  480        ['conv2d_151[0][0]']
#  Normalization)
#
#  batch_normalization_150 (Batch  (None, 12, 12, 160)  480        ['conv2d_156[0][0]']
#  Normalization)
#
#  activation_145 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_145[0][0]']
#
#  activation_150 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_150[0][0]']
#
#  conv2d_152 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_145[0][0]']
#
#  conv2d_157 (Conv2D)            (None, 12, 12, 160)  179200      ['activation_150[0][0]']
#
#  batch_normalization_146 (Batch  (None, 12, 12, 160)  480        ['conv2d_152[0][0]']
#  Normalization)
#
#  batch_normalization_151 (Batch  (None, 12, 12, 160)  480        ['conv2d_157[0][0]']
#  Normalization)
#
#  activation_146 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_146[0][0]']
#
#  activation_151 (Activation)    (None, 12, 12, 160)  0           ['batch_normalization_151[0][0]']
#
#  average_pooling2d_14 (AverageP  (None, 12, 12, 768)  0          ['mixed5[0][0]']
#  ooling2D)
#
#  conv2d_150 (Conv2D)            (None, 12, 12, 192)  147456      ['mixed5[0][0]']
#
#  conv2d_153 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_146[0][0]']
#
#  conv2d_158 (Conv2D)            (None, 12, 12, 192)  215040      ['activation_151[0][0]']
#
#  conv2d_159 (Conv2D)            (None, 12, 12, 192)  147456      ['average_pooling2d_14[0][0]']
#
#  batch_normalization_144 (Batch  (None, 12, 12, 192)  576        ['conv2d_150[0][0]']
#  Normalization)
#
#  batch_normalization_147 (Batch  (None, 12, 12, 192)  576        ['conv2d_153[0][0]']
#  Normalization)
#
#  batch_normalization_152 (Batch  (None, 12, 12, 192)  576        ['conv2d_158[0][0]']
#  Normalization)
#
#  batch_normalization_153 (Batch  (None, 12, 12, 192)  576        ['conv2d_159[0][0]']
#  Normalization)
#
#  activation_144 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_144[0][0]']
#
#  activation_147 (Activation)    (None, 12, 12, 192)  0           ['batch_normalization_147[0][0]']
#
# ...
#
#  activation_174 (Activation)    (None, 5, 5, 448)    0           ['batch_normalization_174[0][0]']
#
#  conv2d_177 (Conv2D)            (None, 5, 5, 384)    491520      ['mixed8[0][0]']
#
#  conv2d_181 (Conv2D)            (None, 5, 5, 384)    1548288     ['activation_174[0][0]']
#
#  batch_normalization_171 (Batch  (None, 5, 5, 384)   1152        ['conv2d_177[0][0]']
#  Normalization)
#
#  batch_normalization_175 (Batch  (None, 5, 5, 384)   1152        ['conv2d_181[0][0]']
#  Normalization)
#
#  activation_171 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_171[0][0]']
#
#  activation_175 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_175[0][0]']
#
#  conv2d_178 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_171[0][0]']
#
#  conv2d_179 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_171[0][0]']
#
#  conv2d_182 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_175[0][0]']
#
#  conv2d_183 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_175[0][0]']
#
#  average_pooling2d_16 (AverageP  (None, 5, 5, 1280)  0           ['mixed8[0][0]']
#  ooling2D)
#
#  conv2d_176 (Conv2D)            (None, 5, 5, 320)    409600      ['mixed8[0][0]']
#
#  batch_normalization_172 (Batch  (None, 5, 5, 384)   1152        ['conv2d_178[0][0]']
#  Normalization)
#
#  batch_normalization_173 (Batch  (None, 5, 5, 384)   1152        ['conv2d_179[0][0]']
#  Normalization)
#
#  batch_normalization_176 (Batch  (None, 5, 5, 384)   1152        ['conv2d_182[0][0]']
#  Normalization)
#
#  batch_normalization_177 (Batch  (None, 5, 5, 384)   1152        ['conv2d_183[0][0]']
#  Normalization)
#
#  conv2d_184 (Conv2D)            (None, 5, 5, 192)    245760      ['average_pooling2d_16[0][0]']
#
#  batch_normalization_170 (Batch  (None, 5, 5, 320)   960         ['conv2d_176[0][0]']
#  Normalization)
#
#  activation_172 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_172[0][0]']
#
#  activation_173 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_173[0][0]']
#
#  activation_176 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_176[0][0]']
#
#  activation_177 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_177[0][0]']
#
#  batch_normalization_178 (Batch  (None, 5, 5, 192)   576         ['conv2d_184[0][0]']
#  Normalization)
#
#  activation_170 (Activation)    (None, 5, 5, 320)    0           ['batch_normalization_170[0][0]']
#
#  mixed9_0 (Concatenate)         (None, 5, 5, 768)    0           ['activation_172[0][0]',
#                                                                   'activation_173[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 5, 5, 768)    0           ['activation_176[0][0]',
#                                                                   'activation_177[0][0]']
#
#  activation_178 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_178[0][0]']
#
#  mixed9 (Concatenate)           (None, 5, 5, 2048)   0           ['activation_170[0][0]',
#                                                                   'mixed9_0[0][0]',
#                                                                   'concatenate_2[0][0]',
#                                                                   'activation_178[0][0]']
#
#  conv2d_189 (Conv2D)            (None, 5, 5, 448)    917504      ['mixed9[0][0]']
#
#  batch_normalization_183 (Batch  (None, 5, 5, 448)   1344        ['conv2d_189[0][0]']
#  Normalization)
#
#  activation_183 (Activation)    (None, 5, 5, 448)    0           ['batch_normalization_183[0][0]']
#
#  conv2d_186 (Conv2D)            (None, 5, 5, 384)    786432      ['mixed9[0][0]']
#
#  conv2d_190 (Conv2D)            (None, 5, 5, 384)    1548288     ['activation_183[0][0]']
#
#  batch_normalization_180 (Batch  (None, 5, 5, 384)   1152        ['conv2d_186[0][0]']
#  Normalization)
#
#  batch_normalization_184 (Batch  (None, 5, 5, 384)   1152        ['conv2d_190[0][0]']
#  Normalization)
#
#  activation_180 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_180[0][0]']
#
#  activation_184 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_184[0][0]']
#
#  conv2d_187 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_180[0][0]']
#
#  conv2d_188 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_180[0][0]']
#
#  conv2d_191 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_184[0][0]']
#
#  conv2d_192 (Conv2D)            (None, 5, 5, 384)    442368      ['activation_184[0][0]']
#
#  average_pooling2d_17 (AverageP  (None, 5, 5, 2048)  0           ['mixed9[0][0]']
#  ooling2D)
#
#  conv2d_185 (Conv2D)            (None, 5, 5, 320)    655360      ['mixed9[0][0]']
#
#  batch_normalization_181 (Batch  (None, 5, 5, 384)   1152        ['conv2d_187[0][0]']
#  Normalization)
#
#  batch_normalization_182 (Batch  (None, 5, 5, 384)   1152        ['conv2d_188[0][0]']
#  Normalization)
#
#  batch_normalization_185 (Batch  (None, 5, 5, 384)   1152        ['conv2d_191[0][0]']
#  Normalization)
#
#  batch_normalization_186 (Batch  (None, 5, 5, 384)   1152        ['conv2d_192[0][0]']
#  Normalization)
#
#  conv2d_193 (Conv2D)            (None, 5, 5, 192)    393216      ['average_pooling2d_17[0][0]']
#
#  batch_normalization_179 (Batch  (None, 5, 5, 320)   960         ['conv2d_185[0][0]']
#  Normalization)
#
#  activation_181 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_181[0][0]']
#
#  activation_182 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_182[0][0]']
#
#  activation_185 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_185[0][0]']
#
#  activation_186 (Activation)    (None, 5, 5, 384)    0           ['batch_normalization_186[0][0]']
#
#  batch_normalization_187 (Batch  (None, 5, 5, 192)   576         ['conv2d_193[0][0]']
#  Normalization)
#
#  activation_179 (Activation)    (None, 5, 5, 320)    0           ['batch_normalization_179[0][0]']
#
#  mixed9_1 (Concatenate)         (None, 5, 5, 768)    0           ['activation_181[0][0]',
#                                                                   'activation_182[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 5, 5, 768)    0           ['activation_185[0][0]',
#                                                                   'activation_186[0][0]']
#
#  activation_187 (Activation)    (None, 5, 5, 192)    0           ['batch_normalization_187[0][0]']
#
#  mixed10 (Concatenate)          (None, 5, 5, 2048)   0           ['activation_179[0][0]',
#                                                                   'mixed9_1[0][0]',
#                                                                   'concatenate_3[0][0]',
#                                                                   'activation_187[0][0]']
#
#  flatten_9 (Flatten)            (None, 51200)        0           ['mixed10[0][0]']
#
#  dense_18 (Dense)               (None, 256)          13107456    ['flatten_9[0][0]']
#
#  dropout_7 (Dropout)            (None, 256)          0           ['dense_18[0][0]']
#
#  dense_19 (Dense)               (None, 8)            2056        ['dropout_7[0][0]']
#
# ==================================================================================================
# Total params: 34,912,296
# Trainable params: 13,109,512
# Non-trainable params: 21,802,784
# __________________________________________________________________________________________________

# %% [markdown]
# Model compilation of Normal CNN

# %%
#model1 compilation
model1.compile(optimizer=Adam(lr = 0.001),
              loss='categorical_crossentropy',
              metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %% [markdown]
# Model compilation of VGG16

# %%
#model2 compilation
model2.compile(optimizer=Adam(lr = 0.001),
               loss=keras.losses.categorical_crossentropy,
               metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %% [markdown]
# Model compilation of VGG19

# %%
model3.compile(optimizer=Adam(lr = 0.001), loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %% [markdown]
# Model compilation of Inception V3

# %%
# Compile the model
model4.compile(optimizer=Adam(lr=0.001), loss=keras.losses.categorical_crossentropy, metrics=['accuracy'])
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.

# %% [markdown]
# Defining epochs number,step size of train and validation

# %%
TRAINING_NUM = train_generator.n # or train_generator.samples
VALID_NUM = val_generator.n # or val_genertor.sample
epochs = 10

STEP_SIZE_TRAIN = TRAINING_NUM // batch_size
STEP_SIZE_VALID = VALID_NUM // batch_size

# %% [markdown]
# Training Normal CNN model

# %%
# Train the model on the training set and validate on the validation set

history1 = model1.fit(train_generator,
                      validation_data=val_generator,
                      epochs=epochs)
# Out:
# Epoch 1/10
# 100/100 [==============================] - 14s 118ms/step - loss: 1.6982 - accuracy: 0.3772 - val_loss: 1.1233 - val_accuracy: 0.6212
# Epoch 2/10
# 100/100 [==============================] - 10s 102ms/step - loss: 0.8455 - accuracy: 0.6934 - val_loss: 0.6783 - val_accuracy: 0.7475
# Epoch 3/10
# 100/100 [==============================] - 10s 97ms/step - loss: 0.5005 - accuracy: 0.8231 - val_loss: 0.4785 - val_accuracy: 0.8150
# Epoch 4/10
# 100/100 [==============================] - 11s 114ms/step - loss: 0.2542 - accuracy: 0.9141 - val_loss: 0.4392 - val_accuracy: 0.8388
# Epoch 5/10
# 100/100 [==============================] - 12s 116ms/step - loss: 0.2312 - accuracy: 0.9225 - val_loss: 0.3396 - val_accuracy: 0.8875
# Epoch 6/10
# 100/100 [==============================] - 9s 92ms/step - loss: 0.1484 - accuracy: 0.9506 - val_loss: 0.4855 - val_accuracy: 0.8462
# Epoch 7/10
# 100/100 [==============================] - 11s 105ms/step - loss: 0.1309 - accuracy: 0.9541 - val_loss: 0.3281 - val_accuracy: 0.8950
# Epoch 8/10
# 100/100 [==============================] - 10s 105ms/step - loss: 0.0504 - accuracy: 0.9844 - val_loss: 0.4417 - val_accuracy: 0.8737
# Epoch 9/10
# 100/100 [==============================] - 10s 103ms/step - loss: 0.0614 - accuracy: 0.9794 - val_loss: 0.4728 - val_accuracy: 0.8675
# Epoch 10/10
# 100/100 [==============================] - 9s 93ms/step - loss: 0.0907 - accuracy: 0.9684 - val_loss: 0.3728 - val_accuracy: 0.8675

# %% [markdown]
# Training VGG16 model

# %%
# Fit model to get reasonable weights for newly added layers.
history2 = model2.fit_generator(generator = train_generator,
                             steps_per_epoch = STEP_SIZE_TRAIN,
                             validation_data = val_generator,
                             validation_steps = STEP_SIZE_VALID,
                             epochs = epochs)
# Out:
# Epoch 1/10
# <ipython-input-101-51c7b4a59e70>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history2 = model2.fit_generator(generator = train_generator,
# 100/100 [==============================] - 19s 174ms/step - loss: 0.9337 - accuracy: 0.7241 - val_loss: 0.2639 - val_accuracy: 0.9250
# Epoch 2/10
# 100/100 [==============================] - 17s 169ms/step - loss: 0.2542 - accuracy: 0.9106 - val_loss: 0.1487 - val_accuracy: 0.9638
# Epoch 3/10
# 100/100 [==============================] - 18s 183ms/step - loss: 0.1123 - accuracy: 0.9719 - val_loss: 0.1044 - val_accuracy: 0.9725
# Epoch 4/10
# 100/100 [==============================] - 17s 164ms/step - loss: 0.0658 - accuracy: 0.9859 - val_loss: 0.0931 - val_accuracy: 0.9712
# Epoch 5/10
# 100/100 [==============================] - 17s 166ms/step - loss: 0.0541 - accuracy: 0.9906 - val_loss: 0.1064 - val_accuracy: 0.9663
# Epoch 6/10
# 100/100 [==============================] - 17s 169ms/step - loss: 0.0505 - accuracy: 0.9891 - val_loss: 0.0896 - val_accuracy: 0.9737
# Epoch 7/10
# 100/100 [==============================] - 17s 165ms/step - loss: 0.0285 - accuracy: 0.9947 - val_loss: 0.0850 - val_accuracy: 0.9762
# Epoch 8/10
# 100/100 [==============================] - 17s 166ms/step - loss: 0.0263 - accuracy: 0.9947 - val_loss: 0.1041 - val_accuracy: 0.9638
# Epoch 9/10
# 100/100 [==============================] - 18s 184ms/step - loss: 0.0281 - accuracy: 0.9944 - val_loss: 0.0959 - val_accuracy: 0.9712
# Epoch 10/10
# 100/100 [==============================] - 17s 166ms/step - loss: 0.0299 - accuracy: 0.9916 - val_loss: 0.0862 - val_accuracy: 0.9737

# %% [markdown]
# Training VGG19 model

# %%
# Fit model to get reasonable weights for newly added layers.
history3 = model3.fit_generator(generator = train_generator,
                             steps_per_epoch = STEP_SIZE_TRAIN,
                             validation_data = val_generator,
                             validation_steps = STEP_SIZE_VALID,
                             epochs = epochs)
# Out:
# Epoch 1/10
# <ipython-input-102-4527b26b76b0>:2: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history3 = model3.fit_generator(generator = train_generator,
# 100/100 [==============================] - 23s 217ms/step - loss: 1.1561 - accuracy: 0.6581 - val_loss: 0.3793 - val_accuracy: 0.8925
# Epoch 2/10
# 100/100 [==============================] - 20s 200ms/step - loss: 0.3206 - accuracy: 0.8988 - val_loss: 0.1908 - val_accuracy: 0.9525
# Epoch 3/10
# 100/100 [==============================] - 21s 208ms/step - loss: 0.1916 - accuracy: 0.9425 - val_loss: 0.1413 - val_accuracy: 0.9600
# Epoch 4/10
# 100/100 [==============================] - 20s 196ms/step - loss: 0.1174 - accuracy: 0.9706 - val_loss: 0.1477 - val_accuracy: 0.9488
# Epoch 5/10
# 100/100 [==============================] - 21s 209ms/step - loss: 0.1090 - accuracy: 0.9675 - val_loss: 0.1060 - val_accuracy: 0.9700
# Epoch 6/10
# 100/100 [==============================] - 20s 198ms/step - loss: 0.0940 - accuracy: 0.9741 - val_loss: 0.1054 - val_accuracy: 0.9600
# Epoch 7/10
# 100/100 [==============================] - 21s 209ms/step - loss: 0.0541 - accuracy: 0.9866 - val_loss: 0.1059 - val_accuracy: 0.9638
# Epoch 8/10
# 100/100 [==============================] - 20s 196ms/step - loss: 0.0677 - accuracy: 0.9784 - val_loss: 0.1039 - val_accuracy: 0.9663
# Epoch 9/10
# 100/100 [==============================] - 21s 209ms/step - loss: 0.0496 - accuracy: 0.9887 - val_loss: 0.0941 - val_accuracy: 0.9650
# Epoch 10/10
# 100/100 [==============================] - 20s 203ms/step - loss: 0.0379 - accuracy: 0.9916 - val_loss: 0.1118 - val_accuracy: 0.9600

# %% [markdown]
# Training Inception V3 model

# %%
history4 = model4.fit_generator(generator=train_generator,
                              steps_per_epoch=STEP_SIZE_TRAIN,
                              validation_data=val_generator,
                              validation_steps=STEP_SIZE_VALID,
                              epochs=epochs)
# Out:
# Epoch 1/10
# <ipython-input-103-efea30e69054>:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history4 = model4.fit_generator(generator=train_generator,
# 100/100 [==============================] - 17s 128ms/step - loss: 3.5654 - accuracy: 0.7253 - val_loss: 0.2782 - val_accuracy: 0.9200
# Epoch 2/10
# 100/100 [==============================] - 11s 112ms/step - loss: 0.2800 - accuracy: 0.9078 - val_loss: 0.1682 - val_accuracy: 0.9438
# Epoch 3/10
# 100/100 [==============================] - 11s 113ms/step - loss: 0.1999 - accuracy: 0.9366 - val_loss: 0.1672 - val_accuracy: 0.9513
# Epoch 4/10
# 100/100 [==============================] - 12s 115ms/step - loss: 0.1447 - accuracy: 0.9516 - val_loss: 0.1762 - val_accuracy: 0.9450
# Epoch 5/10
# 100/100 [==============================] - 12s 117ms/step - loss: 0.1036 - accuracy: 0.9650 - val_loss: 0.1350 - val_accuracy: 0.9575
# Epoch 6/10
# 100/100 [==============================] - 11s 115ms/step - loss: 0.0730 - accuracy: 0.9753 - val_loss: 0.1284 - val_accuracy: 0.9675
# Epoch 7/10
# 100/100 [==============================] - 11s 111ms/step - loss: 0.0862 - accuracy: 0.9700 - val_loss: 0.1482 - val_accuracy: 0.9588
# Epoch 8/10
# 100/100 [==============================] - 12s 117ms/step - loss: 0.0610 - accuracy: 0.9766 - val_loss: 0.1584 - val_accuracy: 0.9600
# Epoch 9/10
# 100/100 [==============================] - 15s 147ms/step - loss: 0.0916 - accuracy: 0.9634 - val_loss: 0.0960 - val_accuracy: 0.9762
# Epoch 10/10
# 100/100 [==============================] - 12s 117ms/step - loss: 0.0776 - accuracy: 0.9716 - val_loss: 0.1099 - val_accuracy: 0.9688

# %% [markdown]
# Model1 Evalution

# %%
# Evaluate the model on the validation set
val_loss1, val_acc1 = model1.evaluate(val_generator)
print(f'Model 1 Validation loss: {val_loss1*100:.2f}%, Validation accuracy: {val_acc1*100:.2f}%')
# Out:
# 25/25 [==============================] - 2s 71ms/step - loss: 0.3728 - accuracy: 0.8675
# Model 1 Validation loss: 37.28%, Validation accuracy: 86.75%

# %% [markdown]
# Model 2 Evalution

# %%
# Evaluate the model on the validation set
val_loss2, val_acc2 = model2.evaluate(val_generator)
print(f'Model 2 Validation loss: {val_loss2*100:.2f}%, Validation accuracy: {val_acc2*100:.2f}%')
# Out:
# 25/25 [==============================] - 3s 132ms/step - loss: 0.0862 - accuracy: 0.9737
# Model 2 Validation loss: 8.62%, Validation accuracy: 97.37%

# %% [markdown]
# Model3 Evalution

# %%
# Evaluate the model on the validation set
val_loss3, val_acc3 = model3.evaluate(val_generator)
print(f'Model 1 Validation loss: {val_loss3*100:.2f}%, Validation accuracy: {val_acc3*100:.2f}%')
# Out:
# 25/25 [==============================] - 4s 160ms/step - loss: 0.1118 - accuracy: 0.9600
# Model 1 Validation loss: 11.18%, Validation accuracy: 96.00%

# %% [markdown]
# Model4 Evalution

# %%
# Evaluate the model on the validation set
val_loss4, val_acc4 = model4.evaluate(val_generator)
print(f'Model 1 Validation loss: {val_loss4*100:.2f}%, Validation accuracy: {val_acc4*100:.2f}%')
# Out:
# 25/25 [==============================] - 2s 88ms/step - loss: 0.1099 - accuracy: 0.9688
# Model 1 Validation loss: 10.99%, Validation accuracy: 96.88%

# %% [markdown]
# Saving All Model

# %%
from keras.models import Model

# Save the model
model1.save('/content/drive/MyDrive/Mango Datasets/ModelWithH5/model1.h5')

model2.save('/content/drive/MyDrive/Mango Datasets/ModelWithH5/model2.h5')
model3.save('/content/drive/MyDrive/Mango Datasets/ModelWithH5/model3.h5')
model4.save('/content/drive/MyDrive/Mango Datasets/ModelWithH5/model4.h5')

# %% [markdown]
# Comparing of all model accuracy vs validation accuracy

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 6))

# Plot 1 - Model 1
axes[0, 0].plot(history1.history['accuracy'])
axes[0, 0].plot(history1.history['val_accuracy'])
axes[0, 0].set_title('Model1 Accuracy')
axes[0, 0].set_ylabel('Accuracy')
axes[0, 0].set_xlabel('Epoch')
axes[0, 0].legend(['Accuracy', 'Val Accuracy'])

# Plot 2 - Model 2
axes[0, 1].plot(history2.history['accuracy'])
axes[0, 1].plot(history2.history['val_accuracy'])
axes[0, 1].set_title('Model2 Accuracy')
axes[0, 1].set_ylabel('Accuracy')
axes[0, 1].set_xlabel('Epoch')
axes[0, 1].legend(['Accuracy', 'Val Accuracy'])

# Plot 3 - Model 3
axes[1, 0].plot(history3.history['accuracy'])
axes[1, 0].plot(history3.history['val_accuracy'])
axes[1, 0].set_title('Model3 Accuracy')
axes[1, 0].set_ylabel('Accuracy')
axes[1, 0].set_xlabel('Epoch')
axes[1, 0].legend(['Accuracy', 'Val Accuracy'])

# Plot 4 - Model 4
axes[1, 1].plot(history4.history['accuracy'])
axes[1, 1].plot(history4.history['val_accuracy'])
axes[1, 1].set_title('Model4 Accuracy')
axes[1, 1].set_ylabel('Accuracy')
axes[1, 1].set_xlabel('Epoch')
axes[1, 1].legend(['Accuracy', 'Val Accuracy'])

plt.tight_layout()  # Adjust spacing between subplots
plt.show()

# %% [markdown]
# Comparing of all model's losses vs validation loss

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 6))
#plt.title('Comparison of Epochs by Loss vs val Loss')
# Plot 1 - Model 1
axes[0, 0].plot(history1.history['loss'])
axes[0, 0].plot(history1.history['val_loss'])
axes[0, 0].set_title('Model1 Loss vs Val Loss')
axes[0, 0].set_ylabel('Loss')
axes[0, 0].set_xlabel('Epoch')
axes[0, 0].legend(['Loss', 'Val loss'])

# Plot 2 - Model 2
axes[0, 1].plot(history2.history['loss'])
axes[0, 1].plot(history2.history['val_loss'])
axes[0, 1].set_title('Model2 Loss vs Val Loss')
axes[0, 1].set_ylabel('Loss')
axes[0, 1].set_xlabel('Epoch')
axes[0, 1].legend(['Loss', 'Val loss'])

# Plot 3 - Model 3
axes[1, 0].plot(history3.history['loss'])
axes[1, 0].plot(history3.history['val_loss'])
axes[1, 0].set_title('Model3 Loss vs Val Loss')
axes[1, 0].set_ylabel('Loss')
axes[1, 0].set_xlabel('Epoch')
axes[1, 0].legend(['Loss', 'Val loss'])

# Plot 4 - Model 4
axes[1, 1].plot(history4.history['loss'])
axes[1, 1].plot(history4.history['val_loss'])
axes[1, 1].set_title('Model4 Loss vs Val Loss')
axes[1, 1].set_ylabel('Loss')
axes[1, 1].set_xlabel('Epoch')
axes[1, 1].legend(['Loss', 'Val loss'])

plt.tight_layout()  # Optional - adjust spacing between subplots
plt.show()

# %% [markdown]
# Printing keys to check how it showing error<br>
# after printing this i see that there is no keys in model1.history.history.keys()<br>
# then the last one is working good.

# %%
print(model1.history.history.keys())
print(history1.history.keys())
# Out:
# dict_keys([])
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# Model bar compare

# %%
categories = [i for i in range(1, 11)]
accuracy1 = history1.history['accuracy']
accuracy2 = history2.history['accuracy']
accuracy3 = history3.history['accuracy']
accuracy4 = history4.history['accuracy']

# Set the width of each bar
barWidth = 0.2

# Set the positions of the bars on the x-axis
r1 = np.arange(len(categories))
r2 = [x + barWidth for x in r1]
r3 = [x + 2 * barWidth for x in r1]
r4 = [x + 3 * barWidth for x in r1]

# Create a grouped bar plot
plt.bar(r1, accuracy1, color='blue', width=barWidth, edgecolor='black', label='Acc1')
plt.bar(r2, accuracy2, color='red', width=barWidth, edgecolor='black', label='Acc2')
plt.bar(r3, accuracy3, color='green', width=barWidth, edgecolor='black', label='Acc3')
plt.bar(r4, accuracy4, color='orange', width=barWidth, edgecolor='black', label='Acc4')

# Add labels and title
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Comparison of Epochs by Accuracy - Barchart')
plt.xticks([r + 1.5 * barWidth for r in range(len(categories))], categories)

# Add a legend
plt.legend()

# Show the plot
plt.show()

# %% [markdown]
# Accuracy Score comparing of 4 model

# %%
plt.title('Comparison of Epochs by Accuracy - Graph')
plt.plot(history1.history['accuracy'],label='Model 1')
plt.plot(history2.history['accuracy'],label='Model 2')
plt.plot(history3.history['accuracy'],label='Model 3')
plt.plot(history4.history['accuracy'],label='Model 4')
plt.xlabel('Epochs')
plt.ylabel('Accuracy Score')
plt.legend()

# %% [markdown]
# Saving all model for next use

# %%
# Save history object using pickle


# Save history1 object
with open('history1.pkl', 'wb') as f:
    pickle.dump(history1.history, f)

# Save history2 object
with open('history2.pkl', 'wb') as f:
    pickle.dump(history2.history, f)

# Save history3 object
with open('history3.pkl', 'wb') as f:
    pickle.dump(history3.history, f)

# Save history4 object
with open('history4.pkl', 'wb') as f:
    pickle.dump(history4.history, f)

# %% [markdown]
# Saving file to the Drive in My History Model folder

# %%
import shutil

# Define the source directory path
source_dir = '/content/'

# Define the destination directory path on Google Drive
destination_dir = '/content/drive/MyDrive/Mango Datasets/History Model 2'

# Copy history files to the destination directory
shutil.copy(source_dir + 'history1.pkl', destination_dir)
shutil.copy(source_dir + 'history2.pkl', destination_dir)

shutil.copy(source_dir + 'history3.pkl', destination_dir)
shutil.copy(source_dir + 'history4.pkl', destination_dir)
# Out:
# '/content/drive/MyDrive/Mango Datasets/History Model 2/history4.pkl'

# %% [markdown]
# Load model to the working /content/ of colab platform

# %%
# Define the source directory path on Google Drive
source_dir = '/content/drive/MyDrive/Mango Datasets/History Model/'

# Define the destination directory path in Colab content
destination_dir = '/content/'

# Move history files to the destination directory
shutil.copy(source_dir + 'history1.pkl', destination_dir)
shutil.copy(source_dir + 'history2.pkl', destination_dir)

shutil.copy(source_dir + 'history3.pkl', destination_dir)
shutil.copy(source_dir + 'history4.pkl', destination_dir)
# Out:
# '/content/history4.pkl'

# %% [markdown]
# Load history file from /content/ folder and a plot using saved model

# %%
# Load history1 object
with open('history1.pkl', 'rb') as f:
    loaded_history1 = pickle.load(f)

# Load history2 object
with open('history2.pkl', 'rb') as f:
    loaded_history2 = pickle.load(f)

# Load history3 object
with open('history3.pkl', 'rb') as f:
    loaded_history3 = pickle.load(f)

# Load history4 object
with open('history4.pkl', 'rb') as f:
    loaded_history4 = pickle.load(f)

# Plot each history object
plt.plot(loaded_history1['accuracy'], label='acc1')
plt.plot(loaded_history2['accuracy'], label='acc2')

plt.plot(loaded_history3['accuracy'], label='acc3')
plt.plot(loaded_history4['accuracy'], label='acc4')

plt.title('Comparison of Epochs by Accuracy - Graph')
plt.xlabel('Epochs')
plt.ylabel('Accuracy Score')
plt.legend()
plt.show()

# %% [markdown]
# Loading model with different way

# %%
# Define the directory path containing the history pickle files
directory = '/content/drive/MyDrive/Mango Datasets/History Model/'

# Initialize a dictionary to store loaded histories
loaded_histories = {}

# Iterate over the pickle files in the directory
for filename in os.listdir(directory):
    if filename.endswith('.pkl'):
        # Load each history object
        with open(os.path.join(directory, filename), 'rb') as f:
            history_name = filename.split('.')[0]
            loaded_histories[history_name] = pickle.load(f)

# Plot each loaded history object
for history_name, history_data in loaded_histories.items():
    plt.plot(history_data['accuracy'], label=history_name)

plt.title('Comparison of Epochs by Accuracy - Graph')
plt.xlabel('Epochs')
plt.ylabel('Accuracy Score')
plt.legend()
plt.show()

# %% [markdown]
# Load the saved model from drive

# %%
from keras.models import load_model
import cv2
# Load the model
loaded_model1 = load_model('/content/drive/MyDrive/Mango Datasets/ModelWithH5/model1.h5')
loaded_model2 = load_model('/content/drive/MyDrive/Mango Datasets/ModelWithH5/model2.h5')
loaded_model3 = load_model('/content/drive/MyDrive/Mango Datasets/ModelWithH5/model3.h5')
loaded_model4 = load_model('/content/drive/MyDrive/Mango Datasets/ModelWithH5/model4.h5')

# %% [markdown]
# Prediction for 8 different classes

# %%
# Load and preprocess the image
for i in range(1,9):
    image_path = '/content/drive/MyDrive/Mango Datasets/Check/mango'+str(i)+'.jpg'; 
    image = cv2.imread(image_path)
    image = cv2.resize(image, (224, 224))
    image = image / 255.0
    image = np.expand_dims(image, axis=0)

    # Make predictions
    predictions1 = loaded_model1.predict(image)
    predictions2 = loaded_model2.predict(image)
    predictions3 = loaded_model3.predict(image)
    predictions4 = loaded_model4.predict(image)

    # Get the predicted class
    predicted_class_index1 = np.argmax(predictions1)
    predicted_class_index2 = np.argmax(predictions2)
    predicted_class_index3 = np.argmax(predictions3)
    predicted_class_index4 = np.argmax(predictions4)



    predicted_class1 = class_labels[predicted_class_index1]
    predicted_class2 = class_labels[predicted_class_index2]
    predicted_class3 = class_labels[predicted_class_index3]
    predicted_class4 = class_labels[predicted_class_index4]

    print("\nFor :", i)

    print("Predicted class using Model1: ", predicted_class1)
    print("Predicted class using Model2: ", predicted_class2)
    print("Predicted class using Model3: ", predicted_class3)
    print("Predicted class using Model4: ", predicted_class4)
# Out:
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 36ms/step
#
# For : 1
# Predicted class using Model1:  Sooty Mould
# Predicted class using Model2:  Die Back
# Predicted class using Model3:  Die Back
# Predicted class using Model4:  Die Back
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 30ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 42ms/step
#
# For : 2
# Predicted class using Model1:  Powdery Mildew
# Predicted class using Model2:  Sooty Mould
# Predicted class using Model3:  Sooty Mould
# Predicted class using Model4:  Anthracnose
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 27ms/step
# 1/1 [==============================] - 0s 39ms/step
#
# For : 3
# Predicted class using Model1:  Sooty Mould
# Predicted class using Model2:  Cutting Weevil
# Predicted class using Model3:  Cutting Weevil
# Predicted class using Model4:  Cutting Weevil
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 28ms/step
#
# For : 4
# Predicted class using Model1:  Healthy
# Predicted class using Model2:  Powdery Mildew
# Predicted class using Model3:  Powdery Mildew
# Predicted class using Model4:  Powdery Mildew
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 25ms/step
#
# For : 5
# Predicted class using Model1:  Healthy
# Predicted class using Model2:  Healthy
# Predicted class using Model3:  Healthy
# Predicted class using Model4:  Anthracnose
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 27ms/step
#
# For : 6
# Predicted class using Model1:  Healthy
# Predicted class using Model2:  Bacterial Canker
# Predicted class using Model3:  Bacterial Canker
# Predicted class using Model4:  Bacterial Canker
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 25ms/step
#
# For : 7
# Predicted class using Model1:  Healthy
# Predicted class using Model2:  Gall Midge
# Predicted class using Model3:  Gall Midge
# Predicted class using Model4:  Bacterial Canker
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 26ms/step
#
# For : 8
# Predicted class using Model1:  Healthy
# Predicted class using Model2:  Sooty Mould
# Predicted class using Model3:  Sooty Mould
# Predicted class using Model4:  Sooty Mould
